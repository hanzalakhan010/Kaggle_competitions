# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('./train.csv')
df.head()
len(df.columns)
df.drop(columns=['Id','Alley','GarageFinish','MiscFeature','Utilities_NoSeWa'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /media/hanzalak/Hanzala/Projects/Kaggle_competitions/home-data-for-ml-course/model.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/media/hanzalak/Hanzala/Projects/Kaggle_competitions/home-data-for-ml-course/model.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df.head()
#       <a href='vscode-notebook-cell:/media/hanzalak/Hanzala/Projects/Kaggle_competitions/home-data-for-ml-course/model.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> len(df.columns)
# ----> <a href='vscode-notebook-cell:/media/hanzalak/Hanzala/Projects/Kaggle_competitions/home-data-for-ml-course/model.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> df.drop(columns=['Id','Alley','GarageFinish','MiscFeature','Utilities_NoSeWa'],inplace=True)
#
# ...

# %%
Categorical = ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'SaleType', 'SaleCondition']
len(Categorical)
# Out:
# 40

# %%
discrete = ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'BsmtFullBath', 'BsmtHalfBath', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'YrSold']

# %%
scaler = StandardScaler()
for dis in discrete:
    df[dis] = df[dis].fillna(df[dis].median())
df[discrete] = scaler.fit_transform(df[discrete])

# %%
df = pd.get_dummies(df,columns=Categorical,drop_first=True)

# %%
df.shape
# Out:
# (1460, 239)

# %%
X  = df.drop(columns=['SalePrice'])
y = df["SalePrice"]

# %%
y = np.log(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=.2)

# %%
model = GradientBoostingRegressor(n_estimators=100,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)

mean_squared_error(y_test,y_pred)
# Out:
# 0.015714465687943487

# %%
param_grid = {
    'n_estimators':[80,90,100,100]
}
grid = GridSearchCV(model,param_grid=param_grid,cv=5,n_jobs=-1)
# grid.fit(X,y)

# %%
df_test = pd.read_csv('./test.csv')
df_test.drop(columns=['Id','Alley','GarageFinish','MiscFeature',],inplace=True)
scaler = StandardScaler()
for dis in discrete:
    df_test[dis] = df_test[dis].fillna(df_test[dis].median())
df_test[discrete] = scaler.fit_transform(df_test[discrete])
df_test = pd.get_dummies(df_test,columns=Categorical,drop_first=True)

# %%
len(df_test.columns)
# Out:
# 224

# %%
len(X.columns)
# Out:
# 241

# %%
set(df_test.columns).symmetric_difference (set(X.columns))
# Out:
# {'BsmtFullBath_1',
#  'BsmtFullBath_1.0',
#  'BsmtFullBath_2',
#  'BsmtFullBath_2.0',
#  'BsmtFullBath_3',
#  'BsmtFullBath_3.0',
#  'BsmtHalfBath_1',
#  'BsmtHalfBath_1.0',
#  'BsmtHalfBath_2',
#  'BsmtHalfBath_2.0',
#  'Condition2_RRAe',
#  'Condition2_RRAn',
#  'Condition2_RRNn',
#  'Electrical_Mix',
#  'Exterior1st_ImStucc',
#  'Exterior1st_Stone',
#  'Exterior2nd_Other',
#  'GarageQual_Fa',
#  'Heating_GasA',
#  'Heating_OthW',
#  'HouseStyle_2.5Fin',
#  'PoolQC_Fa',
#  'RoofMatl_CompShg',
#  'RoofMatl_Membran',
#  'RoofMatl_Metal',
#  'RoofMatl_Roll',
#  'Utilities_NoSeWa'}
